# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly as plotly

# %%
health_df = pd.read_csv("data/heath_nutrition_pop_stats_data.csv")
health_df.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  \
# 0  % of females ages 15-49 having comprehensive c...  SH.HIV.KNOW.FE.ZS
# 1  % of males ages 15-49 having comprehensive cor...  SH.HIV.KNOW.MA.ZS
# 2  Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 3  Adults (ages 15+) and children (0-14 years) li...        SH.HIV.TOTL
# 4  Adults (ages 15+) and children (ages 0-14) new...     SH.HIV.INCD.TL
#
#          1960        1961        1962        1963        1964        1965  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2  133.555013  134.159119  134.857912  134.504576  134.105211  133.569626
# ...

# %%
health_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89010 entries, 0 to 89009
# Data columns (total 61 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    89010 non-null  object
#  1   Country Code    89010 non-null  object
#  2   Indicator Name  89010 non-null  object
#  3   Indicator Code  89010 non-null  object
#  4   1960            35482 non-null  float64
#  5   1961            35325 non-null  float64
#  6   1962            35889 non-null  float64
#  7   1963            35452 non-null  float64
#  8   1964            35483 non-null  float64
#  9   1965            35603 non-null  float64
#  10  1966            35538 non-null  float64
#  11  1967            36022 non-null  float64
#  12  1968            35577 non-null  float64
#  13  1969            35630 non-null  float64
#  14  1970            36910 non-null  float64
#  15  1971            37578 non-null  float64
#  16  1972            38015 non-null  float64
# ...

# %%
health_df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  3.548200e+04  3.532500e+04  3.588900e+04  3.545200e+04  3.548300e+04
# mean   4.398856e+06  4.477329e+06  4.483279e+06  4.634875e+06  4.727806e+06
# std    4.948245e+07  5.013205e+07  5.054473e+07  5.192122e+07  5.297849e+07
# min   -2.374024e+00 -2.498824e+00 -3.826648e+06 -3.206682e+00 -3.078607e+00
# 25%    1.907975e+01  2.130000e+01  1.790000e+01  2.228200e+01  2.236877e+01
# 50%    5.282000e+03  5.794000e+03  5.158000e+03  5.945000e+03  6.065000e+03
# 75%    9.993525e+04  1.034000e+05  1.025840e+05  1.078488e+05  1.107500e+05
# max    3.035056e+09  3.076121e+09  3.129064e+09  3.193947e+09  3.259355e+09
#
#                1965          1966          1967          1968          1969  \
# count  3.560300e+04  3.553800e+04  3.602200e+04  3.557700e+04  3.563000e+04
# mean   4.810557e+06  4.923225e+06  4.958680e+06  5.126162e+06  5.229267e+06
# ...

# %% [markdown]
# Synopsis:
# This dataset includes 345 indicators, such as immunization rates, malnutrition prevalence, and vitamin A supplementation rates across 263 countries around the world. Data was collected on a yearly basis from 1960-2016.
# We are looking at something specific from the 345 indicators such as birth rates, death rates, deficiencies, etc.

# %% [markdown]
# # Goal of Project
# Area of focus: Arab World
# Compare Birth vs. Death Rates in relation to Urban vs. Rural
# Scatter Plot to visualize
#
# Draft Below
# Potential for comparison of Urban vs. Rural
# Specific_1: Birth vs. Death Rates
# Specific_2: Compare Arab World to above values
#
# Area of focus: Arab World
# Compare Birth vs. Death Rates in relation to Urban vs. Rural
# Scatter Plot to visualize
#
# If time allows: Compare Arab World to other Geo locations

# %%
# Need to Data Clean
# Missing values for every year - Why; perhaps a principle?
# Remove "Unnamed: 60"
# Sub Data Frame for Arab World
# Find rural and urban populations Indicator codes
# Find birth and death rates Indicator codes

# %%
# Remove indexed column at end of data
health_df = health_df.drop(columns=["Unnamed: 60"])

# %%
health_df.head(5)
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  \
# 0  % of females ages 15-49 having comprehensive c...  SH.HIV.KNOW.FE.ZS
# 1  % of males ages 15-49 having comprehensive cor...  SH.HIV.KNOW.MA.ZS
# 2  Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 3  Adults (ages 15+) and children (0-14 years) li...        SH.HIV.TOTL
# 4  Adults (ages 15+) and children (ages 0-14) new...     SH.HIV.INCD.TL
#
#          1960        1961        1962        1963        1964        1965  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2  133.555013  134.159119  134.857912  134.504576  134.105211  133.569626
# ...

# %%
# Sub data frame for Country Name of Arab World
arab_world_df = health_df[health_df['Country Name'] == 'Arab World']
arab_world_df.head(5)
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  \
# 0  % of females ages 15-49 having comprehensive c...  SH.HIV.KNOW.FE.ZS
# 1  % of males ages 15-49 having comprehensive cor...  SH.HIV.KNOW.MA.ZS
# 2  Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 3  Adults (ages 15+) and children (0-14 years) li...        SH.HIV.TOTL
# 4  Adults (ages 15+) and children (ages 0-14) new...     SH.HIV.INCD.TL
#
#          1960        1961        1962        1963        1964        1965  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2  133.555013  134.159119  134.857912  134.504576  134.105211  133.569626
# ...

# %%
# Indicator Codes for birth per 1000 people, death per 1000 people, urban population, rural population

aw_birth_df = arab_world_df[arab_world_df['Indicator Code'] == 'SP.DYN.CBRT.IN']
aw_death_df = arab_world_df[arab_world_df['Indicator Code'] == 'SP.DYN.CDRT.IN']
aw_urban_df = arab_world_df[arab_world_df['Indicator Code'] == 'SP.URB.TOTL']
aw_rural_df = arab_world_df[arab_world_df['Indicator Code'] == 'SP.RUR.TOTL']

# %%
# POP percentage
aw_urban_percent_df = arab_world_df[arab_world_df['Indicator Code'] == 'SP.URB.TOTL.IN.ZS']
aw_rural_percent_df = arab_world_df[arab_world_df['Indicator Code'] == 'SP.RUR.TOTL.ZS']

# %%
# pulled only columns for years
# then pulled all values per year columns
birth_year_df = aw_birth_df.iloc[:, 4:59]
birth_year_values = birth_year_df.iloc[0,:]

death_year_df = aw_death_df.iloc[:, 4:59]
death_year_values = death_year_df.iloc[0,:]

urban_year_df = aw_urban_df.iloc[:, 4:59]
urban_year_values = urban_year_df.iloc[0,:]

rural_year_df = aw_rural_df.iloc[:, 4:59]
rural_year_values = rural_year_df.iloc[0,:]

urban_percent_df = aw_urban_percent_df.iloc[:, 4:59]
urban_percent_values = urban_percent_df.iloc[0,:]

rural_percent_df = aw_rural_percent_df.iloc[:, 4:59]
rural_percent_values = rural_percent_df.iloc[0,:]

total_population_df = rural_year_values + urban_year_values
total_population_df
# Out:
# 1960     92540534.0
# 1961     95077992.0
# 1962     97711191.0
# 1963    100439395.0
# 1964    103263656.0
# 1965    106184090.0
# 1966    109210743.0
# 1967    112342573.0
# 1968    115557094.0
# 1969    118823872.0
# 1970    122128175.0
# 1971    125439089.0
# 1972    128801209.0
# 1973    132298955.0
# 1974    136044481.0
# 1975    140114424.0
# 1976    144542039.0
# 1977    149296257.0
# 1978    154303887.0
# 1979    159455867.0
# 1980    164670713.0
# 1981    169926632.0
# 1982    175237742.0
# 1983    180606318.0
# 1984    186005735.0
# 1985    191564251.0
# 1986    197202142.0
# 1987    202851923.0
# 1988    208546282.0
# 1989    214250542.0
# 1990    222117305.0
# 1991    228171034.0
# 1992    232417246.0
# 1993    238628852.0
# 1994    244893420.0
# 1995    252591048.0
# 1996    258423164.0
# 1997    264153948.0
# 1998    269795252.0
# 1999    275503565.0
# 2000    281326250.0
# 2001    287291826.0
# 2002    293402563.0
# 2003    299731956.0
# 2004    306387415.0
# ...

# %%
# # Create a figure and axis
# fig, ax1 = plt.subplots()

# # Plot the first line with its y-axis
# ax1.plot(data['x'], data['y1'], 'b-', label='y1 = x^2')
# ax1.set_xlabel('X Axis')
# ax1.set_ylabel('Y1 Axis', color='b')
# ax1.tick_params(axis='y', labelcolor='b')

# # Create a second y-axis and plot the second line
# ax2 = ax1.twinx()
# ax2.plot(data['x'], data['y2'], 'r-', label='y2 = x')
# ax2.set_ylabel('Y2 Axis', color='r')
# ax2.tick_params(axis='y', labelcolor=

# %%
# KEEP
# Urban Pop with Birth / Death per year
fig, ax1 = plt.subplots(figsize=(20,10))

ax1.plot(birth_year_values, color='green', label='Birth')
ax1.plot(death_year_values, color='red', label='Death')
ax1.set_xlabel('Year')
ax1.set_ylabel('Birth & Death Per 1000')
ax1.tick_params(axis='y', labelcolor='b')
plt.xticks(rotation=90)

ax2 = ax1.twinx()
ax2.bar(x=urban_year_values.index, height=urban_year_values, alpha=.3, label='Urban Population')
ax2.bar(x=rural_year_values.index, height=rural_year_values, alpha=.3, label='Rural Population')
ax2.set_ylabel('Urban Population')
ax2.tick_params(axis='y', labelcolor='b')
plt.title('Urban / Rural Births and Deaths per Year with Annual Population Growth in Arab World')

fig.legend(loc='upper right', title='Legend')
plt.show()

# %%
# Urban / Rural Percentage Population Shift vs. Total Population Growth in Arab World
fig, ax1 = plt.subplots(figsize=(20,10))

ax1.plot(urban_percent_values, color='green', label='Urban Percent Values')
ax1.plot(rural_percent_values, color='red', label='Rural Percent Values')
ax1.set_xlabel('Year')
ax1.set_ylabel('Perecent of Total Population')
ax1.tick_params(axis='y', labelcolor='b')
plt.xticks(rotation=90)

ax2 = ax1.twinx()
ax2.bar(x=total_population_df.index, height=total_population_df, alpha=.3, label='Total Population')
ax2.set_ylabel('Population')
ax2.tick_params(axis='y', labelcolor='b')
plt.title('Urban / Rural Percentage Population Shift vs. Total Population Growth in Arab World')

fig.legend(loc='upper right', title='Legend')
plt.show()

# %%
# Rural Pop with Birth / Death per year
fig, ax1 = plt.subplots(figsize=(20,10))

ax1.plot(birth_year_values, color='green', label='Birth')
ax1.plot(death_year_values, color='red', label='Death')
ax1.set_xlabel('Year')
ax1.set_ylabel('Birth & Death Per 1000')
ax1.tick_params(axis='y', labelcolor='b')
plt.xticks(rotation=90)

ax2 = ax1.twinx()
ax2.bar(x=rural_year_values.index, height=rural_year_values, alpha=.4, label='Population')
ax2.set_ylabel('Rural Population')
ax2.tick_params(axis='y', labelcolor='b')
plt.title('Rural Births and Deaths per Year with Annual Population Growth in Arab World')

fig.legend(loc='right', title='Legend')
plt.show()

# %%
# Need to group by Arab World (Arab Speaking Countries)  
# Need to include the year - Count of birth / death per year  
# Urban and Rural codes for color diff
# # Bar Chart approach  
# x = Urban, y = count per year of Birth Rate; 
# x = Urban, y = count per year of Death Rate;  
# x = Rural, y = count per year of Birth Rate;  
# x = Rural, y = count per year of Death Rate;  
# 2,2 or single plot

# %%
# Need to group by Arab World (Arab Speaking Countries)
# Need to include the year - Count of birth / death per year
# x = Urban, y = Birth Rate; 
# x = Urban, y = Death Rate;
# x = Rural, y = Birth Rate;
# x = Rural, y = Death Rate;
# 2,2 or single plot

# %%
# Correlation Graph

# %%
# Latin America & Caribbean
# For further analysis on Monday
# SH.SGR.CRSK.ZS
# SM.POP.NETM
# SL.TLF.TOTL.FE.ZS

# %% [markdown]
# # 2nd Dataset

# %%
caribbean_df = health_df[health_df['Country Name'] == 'Latin America & Caribbean']
#LCN

# %%
caribbean_df
# Out:
#                    Country Name Country Code  \
# 5520  Latin America & Caribbean          LCN
# 5521  Latin America & Caribbean          LCN
# 5522  Latin America & Caribbean          LCN
# 5523  Latin America & Caribbean          LCN
# 5524  Latin America & Caribbean          LCN
# ...                         ...          ...
# 5860  Latin America & Caribbean          LCN
# 5861  Latin America & Caribbean          LCN
# 5862  Latin America & Caribbean          LCN
# 5863  Latin America & Caribbean          LCN
# 5864  Latin America & Caribbean          LCN
#
#                                          Indicator Name     Indicator Code  \
# 5520  % of females ages 15-49 having comprehensive c...  SH.HIV.KNOW.FE.ZS
# 5521  % of males ages 15-49 having comprehensive cor...  SH.HIV.KNOW.MA.ZS
# 5522  Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 5523  Adults (ages 15+) and children (0-14 years) li...        SH.HIV.TOTL
# ...

# %%
# Indicator Codes for birth per 1000 people, death per 1000 people, urban population, rural population

lcn_birth_df = caribbean_df[caribbean_df['Indicator Code'] == 'SP.DYN.CBRT.IN']
lcn_death_df = caribbean_df[caribbean_df['Indicator Code'] == 'SP.DYN.CDRT.IN']
lcn_urban_df = caribbean_df[caribbean_df['Indicator Code'] == 'SP.URB.TOTL']
lcn_rural_df = caribbean_df[caribbean_df['Indicator Code'] == 'SP.RUR.TOTL']
lcn_urban_percent_df = caribbean_df[caribbean_df['Indicator Code'] == 'SP.URB.TOTL.IN.ZS']
lcn_rural_percent_df = caribbean_df[caribbean_df['Indicator Code'] == 'SP.RUR.TOTL.ZS']

# %%
lcn_urban_df
# Out:
#                    Country Name Country Code    Indicator Name Indicator Code  \
# 5855  Latin America & Caribbean          LCN  Urban population    SP.URB.TOTL
#
#              1960         1961         1962         1963         1964  \
# 5855  108703265.0  113547537.0  118625338.0  123899225.0  129344956.0
#
#              1965  ...         2006         2007         2008         2009  \
# 5855  134808228.0  ...  440393772.0  447766479.0  455135169.0  462480578.0
#
#              2010         2011         2012         2013         2014  \
# 5855  469804192.0  477080730.0  484310338.0  491486460.0  498579281.0
#
#              2015
# 5855  505588921.0
#
# [1 rows x 60 columns]

# %%
# pulled only columns for years
# then pulled all values per year columns
lcn_birth_year_df = lcn_birth_df.iloc[:, 4:59]
lcn_birth_year_values = lcn_birth_year_df.iloc[0,:]

lcn_death_year_df = lcn_death_df.iloc[:, 4:59]
lcn_death_year_values = lcn_death_year_df.iloc[0,:]

lcn_urban_year_df = lcn_urban_df.iloc[:, 4:59]
lcn_urban_year_values = lcn_urban_year_df.iloc[0,:]

lcn_rural_year_df = lcn_rural_df.iloc[:, 4:59]
lcn_rural_year_values = lcn_rural_year_df.iloc[0,:]

lcn_urban_percent_df = lcn_urban_percent_df.iloc[:, 4:59]
lcn_urban_percent_values = lcn_urban_percent_df.iloc[0,:]

lcn_rural_percent_df = lcn_rural_percent_df.iloc[:, 4:59]
lcn_rural_percent_values = lcn_rural_percent_df.iloc[0,:]

lcn_total_population_df = lcn_rural_year_values + lcn_urban_year_values



lcn_rural_year_values
# Out:
# 1960    111864716.0
# 1961    113220509.0
# 1962    114561600.0
# 1963    115875756.0
# 1964    117117280.0
# 1965    118391011.0
# 1966    119576784.0
# 1967    120679798.0
# 1968    121706302.0
# 1969    122685794.0
# 1970    123632849.0
# 1971    124513048.0
# 1972    125353878.0
# 1973    126203703.0
# 1974    127006281.0
# 1975    127727205.0
# 1976    128373885.0
# 1977    128935694.0
# 1978    129423507.0
# 1979    129852795.0
# 1980    130205497.0
# 1981    130531701.0
# 1982    130884122.0
# 1983    131216049.0
# 1984    131477594.0
# 1985    131659264.0
# 1986    131791374.0
# 1987    131865992.0
# 1988    131869980.0
# 1989    131831864.0
# 1990    131764024.0
# 1991    131747790.0
# 1992    131740772.0
# 1993    131702612.0
# 1994    131601542.0
# 1995    131459698.0
# 1996    131354409.0
# 1997    131117872.0
# 1998    130812133.0
# 1999    130481742.0
# 2000    130061215.0
# 2001    130013514.0
# 2002    130004644.0
# 2003    129961979.0
# 2004    129871759.0
# ...

# %%
lcn_urban_percent_df
# Out:
#            1968       1969       1970       1971       1972       1973  \
# 5856  55.526276  56.284404  57.037299  57.796575  58.548815  59.276848
#
#           1974       1975       1976       1977  ...       2005       2006  \
# 5856  59.99598  60.714341  61.428658  62.141564  ...  76.942393  77.258611
#
#            2007       2008       2009       2010       2011       2012  \
# 5856  77.569689  77.876488  78.177942  78.475972  78.769864  79.057211
#
#            2013      2014
# 5856  79.338265  79.61294
#
# [1 rows x 47 columns]

# %%
# KEEP
# Urban Pop with Birth / Death per year
fig, ax1 = plt.subplots(figsize=(20,10))

ax1.plot(lcn_birth_year_values, color='green', label='Birth')
ax1.plot(lcn_death_year_values, color='red', label='Death')
ax1.set_xlabel('Year')
ax1.set_ylabel('Birth & Death Per 1000')
ax1.tick_params(axis='y', labelcolor='b')
plt.xticks(rotation=90)

ax2 = ax1.twinx()
ax2.bar(x=lcn_urban_year_values.index, height=lcn_urban_year_values, alpha=.3, label='Urban Population')
ax2.bar(x=lcn_rural_year_values.index, height=lcn_rural_year_values, alpha=.3, label='Rural Population')
ax2.set_ylabel('Urban Population')
ax2.tick_params(axis='y', labelcolor='b')
plt.title('Urban / Rural Births and Deaths per Year with Annual Population Growth in Latin & Caribbean World')

fig.legend(loc='upper right', title='Legend')
plt.show()

# %%
# Urban / Rural Percentage Population Shift vs. Total Population Growth in Latin America & Caribbean 
fig, ax2 = plt.subplots(figsize=(20,10))


ax2.bar(x=lcn_total_population_df.index, height=lcn_total_population_df, alpha=.3, label='Total Population')
ax2.set_ylabel('Population')
ax2.tick_params(axis='y', labelcolor='b')
plt.xticks(rotation=90)

ax1 = ax2.twinx()
ax1.plot(lcn_urban_percent_values, color='green', label='Urban Percent Values')
ax1.plot(lcn_rural_percent_values, color='red', label='Rural Percent Values')
ax1.set_xlabel('Year')
ax1.set_ylabel('Perecent of Total Population')
ax1.tick_params(axis='y', labelcolor='b')


plt.title('Urban / Rural Percentage Population Shift vs. Total Population Growth in Latin America & Caribbean')

fig.legend(loc='upper right', title='Legend')
plt.show()

# %%
lcn_total_population_df
# Out:
# 1960    220567981.0
# 1961    226768046.0
# 1962    233186938.0
# 1963    239774981.0
# 1964    246462236.0
# 1965    253199239.0
# 1966    259969291.0
# 1967    266780595.0
# 1968    273658891.0
# 1969    280645366.0
# 1970    287767867.0
# 1971    295030672.0
# 1972    302413252.0
# 1973    309906517.0
# 1974    317483798.0
# 1975    325124252.0
# 1976    332821930.0
# 1977    340573214.0
# 1978    348394809.0
# 1979    356291928.0
# 1980    364274384.0
# 1981    372333550.0
# 1982    380470043.0
# 1983    388655706.0
# 1984    396869420.0
# 1985    405081031.0
# 1986    413288285.0
# 1987    421483200.0
# 1988    429658603.0
# 1989    437831834.0
# 1990    445984645.0
# 1991    454102750.0
# 1992    462185509.0
# 1993    470248159.0
# 1994    478295739.0
# 1995    486329390.0
# 1996    494370937.0
# 1997    502377986.0
# 1998    510346213.0
# 1999    518179106.0
# 2000    525878817.0
# 2001    533442976.0
# 2002    540878764.0
# 2003    548220165.0
# 2004    555510455.0
# ...

# %%
lcn_urban_percent_values
# Out:
# 1968    55.526276
# 1969    56.284404
# 1970    57.037299
# 1971    57.796575
# 1972    58.548815
# 1973    59.276848
# 1974    59.995980
# 1975    60.714341
# 1976    61.428658
# 1977    62.141564
# 1978    62.851482
# 1979    63.554382
# 1980    64.256202
# 1981    64.942267
# 1982    65.599363
# 1983    66.238486
# 1984    66.871322
# 1985    67.498044
# 1986    68.111516
# 1987    68.713820
# 1988    69.308196
# 1989    69.889841
# 1990    70.455479
# 1991    70.987229
# 1992    71.496127
# 1993    71.992955
# 1994    72.485321
# 1995    72.969000
# 1996    73.429990
# 1997    73.900554
# 1998    74.367962
# 1999    74.819181
# 2000    75.267836
# 2001    75.627477
# 2002    75.964180
# 2003    76.293834
# 2004    76.621185
# 2005    76.942393
# 2006    77.258611
# 2007    77.569689
# 2008    77.876488
# 2009    78.177942
# 2010    78.475972
# 2011    78.769864
# 2012    79.057211
# 2013    79.338265
# 2014    79.612940
# Name: 5856, dtype: float64
